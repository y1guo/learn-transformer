# %%
# %load_ext autoreload
# %autoreload 2
import torch
from model import PositionalEncoding
from utils import DEVICE
import matplotlib.pyplot as plt

# %%
pos_enc = PositionalEncoding(32, 0)

# %%
res = pos_enc(torch.zeros(1, 60, 32).to(DEVICE))

# %%
plt.figure(figsize=(3.5, 4))
plt.imshow(res[0].cpu().detach().numpy(), cmap="Blues")
plt.show()

# %%
plt.figure(figsize=(6, 2.5))
plt.plot(torch.arange(60), res[0, :, 6:10].cpu().detach().numpy())
plt.show()

# %%
a = torch.rand(1, 2, 3, 4)
a
# Out:
# tensor([[[[0.7502, 0.7426, 0.4098, 0.7616],
#           [0.2603, 0.5691, 0.5057, 0.1773],
#           [0.9481, 0.9260, 0.3191, 0.0557]],
#
#          [[0.1451, 0.2990, 0.9278, 0.4541],
#           [0.3045, 0.5959, 0.7071, 0.1205],
#           [0.8474, 0.9261, 0.2110, 0.6648]]]])

# %%
a.reshape(1, 2, 3, 2, 2)
# Out:
# tensor([[[[[0.7502, 0.7426],
#            [0.4098, 0.7616]],
#
#           [[0.2603, 0.5691],
#            [0.5057, 0.1773]],
#
#           [[0.9481, 0.9260],
#            [0.3191, 0.0557]]],
#
#
#          [[[0.1451, 0.2990],
#            [0.9278, 0.4541]],
#
#           [[0.3045, 0.5959],
#            [0.7071, 0.1205]],
#
#           [[0.8474, 0.9261],
#            [0.2110, 0.6648]]]]])
